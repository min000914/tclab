# %% [markdown]
# # CSV -> NPZ

# %% [markdown]
# - 상태: T1, T2, TSP1, TSP2
# - 보상: 목표온도 - 측정온도

# %%
import pandas as pd
import numpy as np
from glob import glob
import os

csv_dir = "/home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv"
csv_dir2= "/home/minchanggi/code/TCLab/data/PID2/csv"

npz_output_path="/home/minchanggi/code/TCLab/data/PID2MPC/NPZ/offline_dataset_1_Q-T.npz"

all_obs=[]
all_next_obs=[]
all_actions=[]
all_rewards=[]
all_terminals=[]

csv_files_1 = sorted(glob(os.path.join(csv_dir,'PID_episode_*_data.csv')))
csv_files_2 = sorted(glob(os.path.join(csv_dir2,"PID_episode_*_data.csv")))
print(len(csv_files_1),len(csv_files_2))

csv_files = csv_files_1 + csv_files_2

for file_path in csv_files:
    df = pd.read_csv(file_path)
    if len(df)<1000:
        continue
    print(file_path)
    obs = df[['T1','T2','TSP1','TSP2']].values[:-1]
    next_obs = df[['T1','T2','TSP1','TSP2']].values[1:]
    actions=df[['Q1','Q2']].values[:-1]
    rewards = -np.linalg.norm(
        df[['T1','T2']].values[:-1] - df[['TSP1','TSP2']].values[:-1],
        axis=1,
        keepdims=True
    )
    terminals=np.zeros((len(obs),1),dtype=np.float32)
    terminals[-1]=0.0
    
    all_obs.append(obs)
    all_next_obs.append(next_obs)
    all_actions.append(actions)
    all_rewards.append(rewards)
    all_terminals.append(terminals)

dataset={
    'observations': np.vstack(all_obs),
    'actions': np.vstack(all_actions),
    'rewards': np.vstack(all_rewards),
    'next_observations': np.vstack(all_next_obs),
    'terminals':np.vstack(all_terminals),
}
np.savez(npz_output_path, **dataset)
print(f"✅ 저장 완료: {dataset['observations'].shape[0]} transitions")
print(f"→ {npz_output_path}")
# Out:
# 50 46
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_10_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_11_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_12_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_13_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_14_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_15_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_16_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_17_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_18_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_19_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_1_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_20_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_21_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_22_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_23_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_24_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_25_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_26_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_27_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_28_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_29_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_2_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_30_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_31_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_32_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_33_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_34_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_35_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_36_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_37_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_38_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_39_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_3_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_40_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_41_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_42_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_43_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_44_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_45_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_46_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_47_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_48_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_49_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_4_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_50_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_5_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_6_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_7_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_8_data.csv
# /home/minchanggi/code/TCLab/data/PID2MPC/PID3/csv/PID_episode_9_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_11_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_12_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_15_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_17_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_18_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_22_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_23_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_28_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_32_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_33_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_34_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_39_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_3_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_40_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_4_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_5_data.csv
# /home/minchanggi/code/TCLab/data/PID2/csv/PID_episode_6_data.csv
# ✅ 저장 완료: 80266 transitions
# → /home/minchanggi/code/TCLab/data/PID2MPC/NPZ/offline_dataset_1_Q-T.npz
